# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data = pd.read_csv("data/dat_311111_1M_v2.csv")
data = data.drop(["Unnamed: 0"], axis = 1)
data.columns
# Out:
# Index(['Sector', 'Description', 'name_sub', 'Sector_sub',
#        'Total Economic mill dollar', 'Total value Added mill dollar',
#        'Employee Com mill dollar', 'Net Tax mill dollar',
#        'Profits mill dollar', 'Direct Economic mill dollar', 'Direct Economic',
#        'CO t', 'NH3 t', 'NOx t', 'PM10 t', 'PM2.5 t', 'SO2 t', 'VOC t',
#        'Total Energy TJ', 'Coal TJ', 'NatGase TJ', 'Petrol TJ', 'Bio/Waste TJ',
#        'NonFossElec TJ', 'Total t CO2e', 'CO2 Fossil t CO2e',
#        'CO2 Process t CO2e', 'CH4 t CO2e', 'N2O t CO2e', 'HFC/PFCs t CO2e',
#        'Fugitive kg', 'Stack kg', 'Total Air kg', 'Surface water kg',
#        'U'ground Water kg', 'Land kg', 'Offiste kg', 'POTW Metal kg',
#        'POTW Nonmetal kg', 'Water Withdrawals Kgal'],
#       dtype='object')

# %%
data.shape
# Out:
# (405, 40)

# %%
data['Sector'] = data['Sector'].astype(str)
data['Description'] = data['Description'].astype(str)
data['name_sub'] = data['name_sub'].astype(str)
data['Sector_sub'] = data['Sector_sub'].astype(str)

data.head()
# Out:
# 0           0.0
# 1      400000.0
# 2      480000.0
# 3      520000.0
# 4      112000.0
#          ...
# 400    812200.0
# 401    812300.0
# 402    812900.0
# 403    813100.0
# 404    814000.0
# Name: Sector_sub, Length: 405, dtype: object

# %%
data.describe()
# Out:
#            Sector     Sector_sub  Total Economic mill dollar  \
# count  396.000000     405.000000                  405.000000
# mean    37.310606  373533.125926                    0.006494
# std     13.986322  140367.083070                    0.050970
# min     11.000000       0.000000                    0.000000
# 25%     32.000000  322110.000000                    0.000068
# 50%     33.000000  333314.000000                    0.000331
# 75%     33.000000  339920.000000                    0.002100
# max     81.000000  814000.000000                    0.988180
#
#        Total value Added mill dollar  Employee Com mill dollar  \
# count                     405.000000                405.000000
# mean                        0.002425                  0.001071
# std                         0.016484                  0.005517
# min                         0.000000                  0.000000
# 25%                         0.000024                  0.000015
# ...

# %%
#data.isnull().sum()
#data.isna().sum()

# %%
for column in data:
    plt.figure()
    sns.distplot(data[column])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
# plot distribtuion remove all zero point for each columns
for column in data:
    plt.figure()
    sns.distplot(data[column][data[column]!=0])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
# sns_pairplot = sns.pairplot(data)
# sns_pairplot.savefig("img/pairplot.png")

# %%
c = data.corr()

# %%
c[c>0.5]
# Out:
#                                 Sector  Sector_sub  \
# Sector                         1.00000     0.99987
# Sector_sub                     0.99987     1.00000
# Total Economic mill dollar         NaN         NaN
# Total value Added mill dollar      NaN         NaN
# Employee Com mill dollar           NaN         NaN
# Net Tax mill dollar                NaN         NaN
# Profits mill dollar                NaN         NaN
# Direct Economic mill dollar        NaN         NaN
# Direct Economic                    NaN         NaN
# CO t                               NaN         NaN
# NH3 t                              NaN         NaN
# NOx t                              NaN         NaN
# PM10 t                             NaN         NaN
# PM2.5 t                            NaN         NaN
# SO2 t                              NaN         NaN
# VOC t                              NaN         NaN
# Total Energy TJ                    NaN         NaN
# ...

# %%
sns.heatmap(data.corr(), cmap='PiYG')

# %% [markdown]
# after review the correlation and the raw data, the negative correlation might be caused by the sector 1111.

# %% [markdown]
# # Linear Regresssion

# %%
data.columns
# Out:
# Index(['Sector', 'Description', 'name_sub', 'Sector_sub',
#        'Total Economic mill dollar', 'Total value Added mill dollar',
#        'Employee Com mill dollar', 'Net Tax mill dollar',
#        'Profits mill dollar', 'Direct Economic mill dollar', 'Direct Economic',
#        'CO t', 'NH3 t', 'NOx t', 'PM10 t', 'PM2.5 t', 'SO2 t', 'VOC t',
#        'Total Energy TJ', 'Coal TJ', 'NatGase TJ', 'Petrol TJ', 'Bio/Waste TJ',
#        'NonFossElec TJ', 'Total t CO2e', 'CO2 Fossil t CO2e',
#        'CO2 Process t CO2e', 'CH4 t CO2e', 'N2O t CO2e', 'HFC/PFCs t CO2e',
#        'Fugitive kg', 'Stack kg', 'Total Air kg', 'Surface water kg',
#        'U'ground Water kg', 'Land kg', 'Offiste kg', 'POTW Metal kg',
#        'POTW Nonmetal kg', 'Water Withdrawals Kgal'],
#       dtype='object')

# %%
Train_data = data.drop(["Sector_sub", "Description", "name_sub"], axis = 1)
Train_data
# Out:
#      Sector  Total Economic mill dollar  Total value Added mill dollar  \
# 0       NaN                    0.008643                       0.003931
# 1       NaN                    0.002689                       0.001830
# 2      48.0                    0.006654                       0.003633
# 3      52.0                    0.030743                       0.021298
# 4      11.0                    0.012999                       0.006590
# ..      ...                         ...                            ...
# 400    81.0                    0.000000                       0.000000
# 401    81.0                    0.000300                       0.000232
# 402    81.0                    0.000224                       0.000132
# 403    81.0                    0.000000                       0.000000
# 404    81.0                    0.000000                       0.000000
#
#      Employee Com mill dollar  Net Tax mill dollar  Profits mill dollar  \
# ...

# %%
import statsmodels.formula.api as smf
# from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
lm = smf.ols(formula='', data=data).fit()
lm.params
# Out:
#   File "<ipython-input-15-090fa2677434>", line 1
#     lm = smf.ols(formula=''Total value Added mill dollar' ~.', data=data).fit()
#                                ^
# SyntaxError: invalid syntax

# %%
lm.summary()
